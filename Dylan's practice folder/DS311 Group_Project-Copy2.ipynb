# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_excel('salary_data_states_corrected.xlsx')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167278 entries, 0 to 167277
# Data columns (total 27 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   CASE_NUMBER                     167278 non-null  object
#  1   CASE_STATUS                     167278 non-null  object
#  2   CASE_RECEIVED_DATE              167278 non-null  object
#  3   DECISION_DATE                   167278 non-null  object
#  4   EMPLOYER_NAME                   167278 non-null  object
#  5   PREVAILING_WAGE_SUBMITTED       167278 non-null  float64
#  6   PREVAILING_WAGE_SUBMITTED_UNIT  167278 non-null  object
#  7   PAID_WAGE_SUBMITTED             167278 non-null  float64
#  8   PAID_WAGE_SUBMITTED_UNIT        167278 non-null  object
#  9   JOB_TITLE                       167278 non-null  object
#  10  WORK_CITY                       167275 non-null  object
#  11  EDUCATION_LEVEL_REQUIRED        11093 non-null   object
# ...

# %%
df.describe()
# Out:
#        PREVAILING_WAGE_SUBMITTED  PAID_WAGE_SUBMITTED  \
# count               1.672780e+05         1.672780e+05
# mean                7.115752e+04         8.164186e+04
# std                 3.874624e+04         4.147703e+04
# min                 5.050000e+00         5.050000e+00
# 25%                 5.447500e+04         6.100000e+04
# 50%                 6.970100e+04         7.700000e+04
# 75%                 8.993700e+04         1.000000e+05
# max                 6.217100e+06         2.500000e+06
#
#        EXPERIENCE_REQUIRED_NUM_MONTHS  PREVAILING_WAGE_PER_YEAR  \
# count                     4965.000000             167210.000000
# mean                        34.692044              74274.868236
# std                         22.317783              25356.245893
# min                          0.000000              10504.000000
# 25%                         12.000000              56880.000000
# 50%                         24.000000              70928.000000
# ...

# %%
df['WORK_STATE'].value_counts(sort = True, ascending = False)
# Out:
# California                  46782
# Texas                       15498
# New York                    11373
# New Jersey                  10198
# Illinois                     7411
# Massachusetts                6848
# Virginia                     6031
# Georgia                      5615
# Pennsylvania                 4725
# Washington                   4610
# Florida                      4064
# Michigan                     3844
# North Carolina               3578
# Maryland                     3275
# Ohio                         3192
# Missouri                     2773
# Arizona                      2570
# Minnesota                    2116
# Connecticut                  2023
# Indiana                      1617
# Colorado                     1614
# Oregon                       1535
# Wisconsin                    1433
# District of Columbia         1370
# Tennessee                    1087
# Iowa                         1012
# Louisiana                     883
# ...

# %%
df_numeric = df.set_index(['WORK_STATE', 'JOB_TITLE', 'PAID_WAGE_PER_YEAR']).select_dtypes('number')
df_numeric.head(21)
# Out:
#                                                                        PREVAILING_WAGE_SUBMITTED  \
# WORK_STATE     JOB_TITLE                           PAID_WAGE_PER_YEAR
# Illinois       SOFTWARE ENGINEER                   62171.0                             6217100.0
# California     Assistant Professor of Marketing    91440.0                             5067600.0
#                SPECIAL EDUCATION TEACHER           49470.0                             4947000.0
# Texas          SCIENCE TEACHER                     43800.0                              251052.0
# Oregon         SENIOR SOFTWARE ENGINEER            170000.0                              84573.0
# California     ORACLE SCM ANALYST/BUSINESS ANALYST 114421.0                             113610.0
#                SENIOR SOFTWARE ENGINEER            145000.0                            1333328.0
# New Jersey     SOFTWARE ENGINEER                   104458.0                             104458.0
# ...

# %%
df['JOB_TITLE'].value_counts(sort = True, ascending = False)
# Out:
# SOFTWARE ENGINEER                                54478
# BUSINESS ANALYST                                 19516
# SENIOR SOFTWARE ENGINEER                         11714
# ASSISTANT PROFESSOR                              10134
# Software Engineer                                 3743
#                                                  ...
# SENIOR SOFTWARE ENGINEER (PRODUCT SPECIALIST)        1
# SOFTWARE ENGINEER - SENIOR KERNEL GENERALIST         1
# SENIOR ORACLE APPS SOFTWARE ENGINEER                 1
# ASSISTANT PROFESSOR OF FINANACE                      1
# BILINGUAL SPECIAL EDUCATION TEACHER ASSISTANT        1
# Name: JOB_TITLE, Length: 12589, dtype: int64

# %%
#JOB_TITLE_SUBGROUP

df['JOB_TITLE_SUBGROUP'].value_counts(sort = True, ascending = False)
# Out:
# software engineer        99364
# business analyst         27811
# assistant professor      18866
# teacher                  13912
# data analyst              3840
# attorney                  1488
# data scientist            1227
# management consultant      770
# Name: JOB_TITLE_SUBGROUP, dtype: int64

# %%
df['PAID_WAGE_PER_YEAR'].describe()
# Out:
# count    1.672780e+05
# mean     8.553277e+04
# std      3.873847e+04
# min      1.050000e+04
# 25%      6.300000e+04
# 50%      7.860000e+04
# 75%      1.000060e+05
# max      2.500000e+06
# Name: PAID_WAGE_PER_YEAR, dtype: float64

# %%
df['PAID_WAGE_PER_YEAR'].max()
# Out:
# 2500000.0

# %%
df.loc[df['WORK_STATE']=='California'].head(21)
# Out:
#             CASE_NUMBER          CASE_STATUS CASE_RECEIVED_DATE DECISION_DATE  \
# 1         A-15061-55212               denied          3/19/2015     3/19/2015
# 2    I-200-13256-001092               denied          9/13/2013     9/23/2013
# 5    I-200-14092-483272               denied           4/2/2014      4/9/2014
# 6    I-200-13084-487292               denied          3/25/2013     3/28/2013
# 9    I-200-14069-400950               denied          3/10/2014     3/18/2014
# 12   I-200-11172-152960  certified-withdrawn          6/21/2011     9/13/2013
# 14   I-200-14027-258414               denied           2/5/2014     2/10/2014
# 17   I-200-13311-440603               denied         11/19/2013    11/22/2013
# 21   I-200-13240-569816               denied          8/29/2013      9/6/2013
# 24   I-200-13045-026419               denied           3/6/2013     3/18/2013
# 59   I-200-14133-980882               denied          5/13/2014     5/20/2014
# ...

# %%
df.loc[df['PAID_WAGE_PER_YEAR'] == df['PAID_WAGE_PER_YEAR'].max(), 'JOB_TITLE_SUBGROUP']
# Out:
# 232    attorney
# Name: JOB_TITLE_SUBGROUP, dtype: object

# %%
df_numeric = df.set_index(['WORK_STATE', 'JOB_TITLE_SUBGROUP', 'PAID_WAGE_PER_YEAR']).select_dtypes('number')
df_numeric.sort_values(
by = ['PAID_WAGE_PER_YEAR'],
ascending=False).head(30)
# Out:
#                                                              PREVAILING_WAGE_SUBMITTED  \
# WORK_STATE           JOB_TITLE_SUBGROUP  PAID_WAGE_PER_YEAR
# District of Columbia attorney            2500000.00                           192379.0
# New York             attorney            2400000.00                           207106.0
# District of Columbia attorney            2400000.00                           188053.0
#                                          2400000.00                           188053.0
#                                          2400000.00                           188053.0
# Alabama              software engineer   1400000.00                           101462.0
# Texas                business analyst    1250784.00                            69306.0
#                                          1250784.00                            69306.0
#                      software engineer   1224800.60                            78915.0
# ...

# %%
df_numeric = df.set_index(['WORK_STATE', 'JOB_TITLE_SUBGROUP', 'PAID_WAGE_PER_YEAR']).select_dtypes('number')
df_numeric.sort_values(
by = ({'PAID_WAGE_PER_YEAR':[software engineer, business analyst]})
ascending=False).head(30)
# Out:
#   File "/var/folders/ht/fx4tjfs51mg4zsl3sfp798mr0000gn/T/ipykernel_9085/3495577266.py", line 3
#     by = ({'PAID_WAGE_PER_YEAR':[software engineer, business analyst]})
#                                           ^
# SyntaxError: invalid syntax
